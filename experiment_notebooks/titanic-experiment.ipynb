# %%
import os
import random
import warnings
from IPython.display import display, HTML

import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression

from auto_categorical_features_transformer import create_categorical_feature_transformations_report, CategoricalTransformationMethods

# %%
warnings.filterwarnings("ignore")

# %%
def _load_titanic_dataset():
    titanic_dataset_df = pd.read_csv('./datasets/titanic/train.csv')

    y = titanic_dataset_df['Survived']
    X = titanic_dataset_df.drop(columns=['Survived'])
    return X, y

# %%
X, y = _load_titanic_dataset()

# %%
one_hot_results = create_categorical_feature_transformations_report(
    X, y,
    transformation_method=CategoricalTransformationMethods.OneHot,
    return_rich_table=True,
    verbose=True
)
one_hot_results.summary_table
# Out:
# transformations evaluation: 100%|██████████████████████████████████████████████████████████████████████| 32/32 [00:14<00:00,  2.16it/s]
# <style>
#   #dp-07d4801f68084a02a446eb172a3c4a15 {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/iframe-resizer/4.3.2/iframeResizer.min.js" integrity="sha512-dnvR4Aebv5bAtJxDunq3eE8puKAJrY9GBJYl9GC6lTOEC76s1dbDfJFcL9GyzpaDW4vlI/UjR8sKbc1j6Ynx6w==" crossorigin="anonymous" referrerpolicy="no-referrer"></script>
# <iframe id="dp-07d4801f68084a02a446eb172a3c4a15" srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&#34;en&#34;&gt;
#   &lt;head&gt;
#     &lt;meta charset=&#34;UTF-8&#34; /&gt;
#     &lt;script src=&#34;https://kit.fontawesome.com/256c714d9a.js&#34;&gt;&lt;/script&gt;
#     &lt;link
#       href=&#34;https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&amp;display=swap&#34;
#       rel=&#34;stylesheet&#34;
#     /&gt;
#     &lt;script&gt;
#       window.dpLocal = true;
#
#         window.dpLocalViewEvent = true;
#         window.dpReportId = &#34;07d4801f68084a02a446eb172a3c4a15&#34;;
#         window.dpAuthorId = &#34;eb2f48ae07524d609bed839239124dfe&#34;;
#
#     &lt;/script&gt;
#
#       &lt;link rel=&#34;stylesheet&#34; href=&#34;https://datapane-cdn.com/v0.15.7/local-report/local-report-base.css&#34;&gt;
#
#     &lt;script&gt;
#       const report = { document: &#34;\u003cReport version=\&#34;1\&#34;\u003e\u003cMeta\u003e\u003cAuthor\u003eAnonymous\u003c/Author\u003e\u003cCreatedOn\u003e2023-02-25T13:41:34Z\u003c/CreatedOn\u003e\u003cTitle\u003eStringified App\u003c/Title\u003e\u003cDescription\u003e\u003c![CDATA[Description]]\u003e\u003c/Description\u003e\u003c/Meta\u003e\u003cInternal/\u003e\u003cPages\u003e\u003cPage\u003e\u003cDataTable type=\&#34;application/vnd.apache.arrow+binary\&#34; size=\&#34;6994\&#34; uploaded_filename=\&#34;dp-tmp-t_qyjg3h.arrow\&#34; rows=\&#34;32\&#34; columns=\&#34;7\&#34; schema=\&#34;[]\&#34; src=\&#34;data:application/vnd.apache.arrow+binary;base64,...\&#34;/\u003e\u003c/Page\u003e\u003c/Pages\u003e\u003c/Report\u003e&#34;, width: &#34;&#34;, output_is_light_prose: false };
#       const htmlHeader = `&lt;style type=&#34;text/css&#34;&gt;:root {
#     --dp-accent-color: #4E46E5;
#     --dp-bg-color: #FFF;
#     --dp-text-align: justify;
#     --dp-font-family: Inter var, ui-sans-serif, system-ui;
# }&lt;/style&gt;`;
#       window.reportProps = { report, htmlHeader };
#     &lt;/script&gt;
#
#       &lt;script type=&#34;module&#34;&gt;
#         import { mountReport } from &#34;https://datapane-cdn.com/v0.15.7/report/index.es.js&#34;;
#         mountReport(window.reportProps);
#       &lt;/script&gt;
#
#   &lt;/head&gt;
#   &lt;body&gt;
#     &lt;main class=&#34;max-w-screen-xl w-full mx-auto&#34;&gt;
#       &lt;div id=&#34;report&#34; class=&#34;w-full&#34;&gt;&lt;/div&gt;
#     &lt;/main&gt;
#     &lt;script src=&#34;https://cdnjs.cloudflare.com/ajax/libs/iframe-resizer/4.3.2/iframeResizer.contentWindow.min.js&#34; integrity=&#34;sha512-14SY6teTzhrLWeL55Q4uCyxr6GQOxF3pEoMxo2mBxXwPRikdMtzKMYWy2B5Lqjr6PHHoGOxZgPaxUYKQrSmu0A==&#34; crossorigin=&#34;anonymous&#34; referrerpolicy=&#34;no-referrer&#34;&gt;&lt;/script&gt;  &lt;/body&gt;
# &lt;/html&gt;" style="border:none;"></iframe>
# <script>
#   iFrameResize({ log: true, checkOrigin: false }, '#dp-07d4801f68084a02a446eb172a3c4a15')
# </script>

# %%
woe_results = create_categorical_feature_transformations_report(
    X, y,
    transformation_method=CategoricalTransformationMethods.WeightOfEvidence,
    return_rich_table=True,
    verbose=True
)
woe_results.summary_table
# Out:
# transformations evaluation: 100%|██████████████████████████████████████████████████████████████████████| 32/32 [00:14<00:00,  2.15it/s]
# <style>
#   #dp-638b461e407049af93d2716dc55ddda6 {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/iframe-resizer/4.3.2/iframeResizer.min.js" integrity="sha512-dnvR4Aebv5bAtJxDunq3eE8puKAJrY9GBJYl9GC6lTOEC76s1dbDfJFcL9GyzpaDW4vlI/UjR8sKbc1j6Ynx6w==" crossorigin="anonymous" referrerpolicy="no-referrer"></script>
# <iframe id="dp-638b461e407049af93d2716dc55ddda6" srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&#34;en&#34;&gt;
#   &lt;head&gt;
#     &lt;meta charset=&#34;UTF-8&#34; /&gt;
#     &lt;script src=&#34;https://kit.fontawesome.com/256c714d9a.js&#34;&gt;&lt;/script&gt;
#     &lt;link
#       href=&#34;https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&amp;display=swap&#34;
#       rel=&#34;stylesheet&#34;
#     /&gt;
#     &lt;script&gt;
#       window.dpLocal = true;
#
#         window.dpLocalViewEvent = true;
#         window.dpReportId = &#34;638b461e407049af93d2716dc55ddda6&#34;;
#         window.dpAuthorId = &#34;eb2f48ae07524d609bed839239124dfe&#34;;
#
#     &lt;/script&gt;
#
#       &lt;link rel=&#34;stylesheet&#34; href=&#34;https://datapane-cdn.com/v0.15.7/local-report/local-report-base.css&#34;&gt;
#
#     &lt;script&gt;
#       const report = { document: &#34;\u003cReport version=\&#34;1\&#34;\u003e\u003cMeta\u003e\u003cAuthor\u003eAnonymous\u003c/Author\u003e\u003cCreatedOn\u003e2023-02-25T13:41:49Z\u003c/CreatedOn\u003e\u003cTitle\u003eStringified App\u003c/Title\u003e\u003cDescription\u003e\u003c![CDATA[Description]]\u003e\u003c/Description\u003e\u003c/Meta\u003e\u003cInternal/\u003e\u003cPages\u003e\u003cPage\u003e\u003cDataTable type=\&#34;application/vnd.apache.arrow+binary\&#34; size=\&#34;6722\&#34; uploaded_filename=\&#34;dp-tmp-zy2u1hm4.arrow\&#34; rows=\&#34;32\&#34; columns=\&#34;7\&#34; schema=\&#34;[]\&#34; src=\&#34;data:application/vnd.apache.arrow+binary;base64,...\&#34;/\u003e\u003c/Page\u003e\u003c/Pages\u003e\u003c/Report\u003e&#34;, width: &#34;&#34;, output_is_light_prose: false };
#       const htmlHeader = `&lt;style type=&#34;text/css&#34;&gt;:root {
#     --dp-accent-color: #4E46E5;
#     --dp-bg-color: #FFF;
#     --dp-text-align: justify;
#     --dp-font-family: Inter var, ui-sans-serif, system-ui;
# }&lt;/style&gt;`;
#       window.reportProps = { report, htmlHeader };
#     &lt;/script&gt;
#
#       &lt;script type=&#34;module&#34;&gt;
#         import { mountReport } from &#34;https://datapane-cdn.com/v0.15.7/report/index.es.js&#34;;
#         mountReport(window.reportProps);
#       &lt;/script&gt;
#
#   &lt;/head&gt;
#   &lt;body&gt;
#     &lt;main class=&#34;max-w-screen-xl w-full mx-auto&#34;&gt;
#       &lt;div id=&#34;report&#34; class=&#34;w-full&#34;&gt;&lt;/div&gt;
#     &lt;/main&gt;
#     &lt;script src=&#34;https://cdnjs.cloudflare.com/ajax/libs/iframe-resizer/4.3.2/iframeResizer.contentWindow.min.js&#34; integrity=&#34;sha512-14SY6teTzhrLWeL55Q4uCyxr6GQOxF3pEoMxo2mBxXwPRikdMtzKMYWy2B5Lqjr6PHHoGOxZgPaxUYKQrSmu0A==&#34; crossorigin=&#34;anonymous&#34; referrerpolicy=&#34;no-referrer&#34;&gt;&lt;/script&gt;  &lt;/body&gt;
# &lt;/html&gt;" style="border:none;"></iframe>
# <script>
#   iFrameResize({ log: true, checkOrigin: false }, '#dp-638b461e407049af93d2716dc55ddda6')
# </script>

# %%
loo_results = create_categorical_feature_transformations_report(
    X, y,
    transformation_method=CategoricalTransformationMethods.LeaveOneOut,
    return_rich_table=True,
    verbose=True
)
loo_results.summary_table
# Out:
# transformations evaluation: 100%|██████████████████████████████████████████████████████████████████████| 32/32 [00:12<00:00,  2.49it/s]
# <style>
#   #dp-bd1a15e45c1a4fd29255add02bdee781 {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/iframe-resizer/4.3.2/iframeResizer.min.js" integrity="sha512-dnvR4Aebv5bAtJxDunq3eE8puKAJrY9GBJYl9GC6lTOEC76s1dbDfJFcL9GyzpaDW4vlI/UjR8sKbc1j6Ynx6w==" crossorigin="anonymous" referrerpolicy="no-referrer"></script>
# <iframe id="dp-bd1a15e45c1a4fd29255add02bdee781" srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&#34;en&#34;&gt;
#   &lt;head&gt;
#     &lt;meta charset=&#34;UTF-8&#34; /&gt;
#     &lt;script src=&#34;https://kit.fontawesome.com/256c714d9a.js&#34;&gt;&lt;/script&gt;
#     &lt;link
#       href=&#34;https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&amp;display=swap&#34;
#       rel=&#34;stylesheet&#34;
#     /&gt;
#     &lt;script&gt;
#       window.dpLocal = true;
#
#         window.dpLocalViewEvent = true;
#         window.dpReportId = &#34;bd1a15e45c1a4fd29255add02bdee781&#34;;
#         window.dpAuthorId = &#34;eb2f48ae07524d609bed839239124dfe&#34;;
#
#     &lt;/script&gt;
#
#       &lt;link rel=&#34;stylesheet&#34; href=&#34;https://datapane-cdn.com/v0.15.7/local-report/local-report-base.css&#34;&gt;
#
#     &lt;script&gt;
#       const report = { document: &#34;\u003cReport version=\&#34;1\&#34;\u003e\u003cMeta\u003e\u003cAuthor\u003eAnonymous\u003c/Author\u003e\u003cCreatedOn\u003e2023-02-25T13:42:02Z\u003c/CreatedOn\u003e\u003cTitle\u003eStringified App\u003c/Title\u003e\u003cDescription\u003e\u003c![CDATA[Description]]\u003e\u003c/Description\u003e\u003c/Meta\u003e\u003cInternal/\u003e\u003cPages\u003e\u003cPage\u003e\u003cDataTable type=\&#34;application/vnd.apache.arrow+binary\&#34; size=\&#34;6906\&#34; uploaded_filename=\&#34;dp-tmp-m2fj11lp.arrow\&#34; rows=\&#34;32\&#34; columns=\&#34;7\&#34; schema=\&#34;[]\&#34; src=\&#34;data:application/vnd.apache.arrow+binary;base64,...\&#34;/\u003e\u003c/Page\u003e\u003c/Pages\u003e\u003c/Report\u003e&#34;, width: &#34;&#34;, output_is_light_prose: false };
#       const htmlHeader = `&lt;style type=&#34;text/css&#34;&gt;:root {
#     --dp-accent-color: #4E46E5;
#     --dp-bg-color: #FFF;
#     --dp-text-align: justify;
#     --dp-font-family: Inter var, ui-sans-serif, system-ui;
# }&lt;/style&gt;`;
#       window.reportProps = { report, htmlHeader };
#     &lt;/script&gt;
#
#       &lt;script type=&#34;module&#34;&gt;
#         import { mountReport } from &#34;https://datapane-cdn.com/v0.15.7/report/index.es.js&#34;;
#         mountReport(window.reportProps);
#       &lt;/script&gt;
#
#   &lt;/head&gt;
#   &lt;body&gt;
#     &lt;main class=&#34;max-w-screen-xl w-full mx-auto&#34;&gt;
#       &lt;div id=&#34;report&#34; class=&#34;w-full&#34;&gt;&lt;/div&gt;
#     &lt;/main&gt;
#     &lt;script src=&#34;https://cdnjs.cloudflare.com/ajax/libs/iframe-resizer/4.3.2/iframeResizer.contentWindow.min.js&#34; integrity=&#34;sha512-14SY6teTzhrLWeL55Q4uCyxr6GQOxF3pEoMxo2mBxXwPRikdMtzKMYWy2B5Lqjr6PHHoGOxZgPaxUYKQrSmu0A==&#34; crossorigin=&#34;anonymous&#34; referrerpolicy=&#34;no-referrer&#34;&gt;&lt;/script&gt;  &lt;/body&gt;
# &lt;/html&gt;" style="border:none;"></iframe>
# <script>
#   iFrameResize({ log: true, checkOrigin: false }, '#dp-bd1a15e45c1a4fd29255add02bdee781')
# </script>

# %%
one_hot_results
# Out:
# CategoricalTransformationResults(transformation_candidate_features=('Pclass', 'Sex', 'SibSp', 'Embarked', 'Parch'), baseline_evaluation_results=transformed_columns          []
# f1                     0.712058
# f1_std                 0.022943
# accuracy               0.767673
# accuracy_std           0.011629
# Name: 0, dtype: object, summary_table=<datapane.client.api.report.blocks.DataTable object at 0x130cb4400>)
